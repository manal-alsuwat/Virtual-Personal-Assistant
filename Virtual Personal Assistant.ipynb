# %% [markdown]
# ### Create your own Virtual Personal Assistant

# %% [markdown]
# We need to install some important packages:
#
#
# *SpeechRecognition : Library for performing speech recognition, with support for several engines and APIs, online and offline.
#
# *Pyttsx3 : Pyttsx is a good text to speech conversion library in python.
#
# *Wikipedia : Wikipedia is a Python library that makes it easy to access and parse data from Wikipedia.

# %% [markdown]
# If you are done installing those packages then we can import them and get back to the code:

# %%
import pyttsx3 
import speech_recognition as sr 
import datetime 
import wikipedia 
import webbrowser 
import os 
import ctypes

# %% [markdown]
# Now, We’ll be initializing a variable and getting the necessary voice parameter we need. For female voice, you can set the value as 1 in the second line and 0 for male voice.

# %%
engine = pyttsx3.init('sapi5') 
voices = engine.getProperty('voices') 
engine.setProperty('voice', voices[1].id) 
def speak(audio): 
	engine.say(audio) 
	engine.runAndWait()

# %% [markdown]
# create another function greetMe and this will be used to greet the user when he runs the program. datetime.datetime.now()

# %%
def greetMe(): 
	hour = int(datetime.datetime.now().hour) 
	if hour>= 0 and hour<12: 
		speak("Good Morning Sir !") 

	elif hour>= 12 and hour<18: 
		speak("Good Afternoon Sir !") 

	else: 
		speak("Good Evening Sir !") 

	assname =("Abdel Azeez") 
	speak("I am your Assistant") 
	speak(assname)

# %% [markdown]
# Here, We’ll be declaring some important functions and conditions which will enhance the functionality of our personal assistant and help him to deliver the output and receive the inputs from the user.

# %%
def usrname(): 
	speak("What should i call you sir") 
	uname = takeCommand() 
	speak("Welcome Mister") 
	speak(uname) 
	
	
	
	print("Welcome Mr.", uname) 
	
	speak("How can i Help you, Sir") 

def takeCommand(): 
	
	r = sr.Recognizer() 
	
	with sr.Microphone() as source: 
		
		print("Listening...") 
		r.pause_threshold = 1
		audio = r.listen(source) 

	try: 
		print("Recognizing...")	 
		query = r.recognize_google(audio, language ='en-in') 
		print(f"User said: {query}\n") 

	except Exception as e: 
		print(e)	 
		print("Unable to Recognizing your voice.") 
		return "None"
	
	return query 




if __name__ == '__main__': 
	clear = lambda: os.system('cls') 
	
	# This Function will clean any 
	# command before execution of this python file 
	clear() 
	greetMe() 
	usrname() 
	
	while True: 
		
		query = takeCommand().lower() 
		
		# All the commands said by user will be 
		# stored here in 'query' and will be 
		# converted to lower case for easily 
		# recognition of command 
		if 'wikipedia' in query: 
			speak('Searching Wikipedia...') 
			query = query.replace("wikipedia", "") 
			results = wikipedia.summary(query, sentences = 3) 
			speak("According to Wikipedia") 
			print(results) 
			speak(results) 
        
		elif 'open youtube' in query: 
			speak("Here you go to Youtube\n") 
			webbrowser.open("youtube.com") 

		elif 'open google' in query: 
			speak("Here you go to Google\n") 
			webbrowser.open("google.com") 

			 

		elif 'what is the time now' in query: 
			strTime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S");print(strTime)	 
			speak(f"Sir, the time is {strTime}")
            

			
		elif 'how are you' in query: 
			speak("I am fine, Thank you") 
			speak("How are you, Sir") 

		elif 'fine' in query or "good" in query: 
			speak("It's good to know that your fine") 

		elif "change my name to" in query: 
			query = query.replace("change my name to", "") 
			assname = query 

		elif "change name" in query: 
			speak("What would you like to call me, Sir ") 
			assname = takeCommand() 
			speak("Thanks for naming me") 

		elif "what's your name" in query or "What is your name" in query: 
			speak("My friends call me Abdel Azeez") 
			



		elif "who made you" in query or "who created you" in query: 
			speak("I have been created by manal alsuwat.") 
			
		

		elif "who i am" in query: 
			speak("If you talk then definately your human.")
             
        

		elif "who are you" in query: 
			speak("I am your virtual assistant created by manal") 

		
		elif "are you robot" in query: 
			speak("yes,I am virtual assistant created by manal")
            
		elif "how much is this" in query: 
			speak("$ 6")        
            
            
        	
		elif 'lock window' in query: 
				speak("locking the device") 
				ctypes.windll.user32.LockWorkStation() 

		
		elif "wikipedia" in query: 
			webbrowser.open("wikipedia.com") 

		
            
            
		elif 'exit' in query: 
			speak("Thanks for giving me your time") 
			exit()
